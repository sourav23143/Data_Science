# %%
print("ABC")
# Out:
# ABC

# %%
# TO CONNECT it with mysql we have to install some my sql connector

# %%
 #without this we are not be able to connect it with my sql
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ERROR: Invalid requirement: '#without': Expected package name at the start of dependency specifier
#     #without
#     ^

# %%
# !pip install mysql-connector-python
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
import mysql.connector as conn

# %%
#to make connection>>

# %%
help(conn.connect())
# Out:
# Help on MySQLConnection in module mysql.connector.connection object:
#
# class MySQLConnection(mysql.connector.abstracts.MySQLConnectionAbstract)
#  |  MySQLConnection(**kwargs: 'Any') -> 'None'
#  |
#  |  Connection to a MySQL Server
#  |
#  |  Method resolution order:
#  |      MySQLConnection
#  |      mysql.connector.abstracts.MySQLConnectionAbstract
#  |      abc.ABC
#  |      builtins.object
#  |
#  |  Methods defined here:
#  |
#  |  __init__(self, **kwargs: 'Any') -> 'None'
#  |      Initialize
#  |
#  |  close(self) -> 'None'
#  |      Disconnects from the MySQL server.
#  |
#  |      This method tries to send a `QUIT` command and close the socket. It raises
#  |      no exceptions.
#  |
#  |      `MySQLConnection.close()` is a synonymous for `MySQLConnection.disconnect()`
#  |      method name and more commonly used.
#  |
#  |      To shut down the connection without sending a `QUIT` command first,
#  |      use `shutdown()`.
#  |
# ...

# %%
mydb = conn.connect(host ="localhost", user= "root", passwd = "Deoghar@baba5")

# %%
mydb  #it is a connection string which basically connected to mysql  #now entire connection detail is inside mydb>> this is pointing to mydatabase

# %%
#if we want to excecute the  sql query using python , we need to create a cursor

#cursor = cursor is like a pointer which is connecting to my database

# %%
cursor = mydb.cursor()  #cursor >> we can give any name to it as it variable

# %%
#whenver we want to write any query , then first step is that we have create a cursor

# %%
#then we have to write query in execute method

cursor.execute("show databases")  #show databases >> list of all data bses in mysql

# %%
#we already executed it but not be able to see the result>>

# %%
cursor.fetchall() #it fetch all the query that we have executed earllier
# Out:
# [('ds_sql',),
#  ('information_schema',),
#  ('mysql',),
#  ('performance_schema',),
#  ('sourav',),
#  ('sys',)]

# %%
#to create a data base

cursor.execute("create database pysqldb")

# %%
cursor.execute("create table pysqldb.pu(studentid INT, firstname VARCHAR(30), lastname VARCHAR(30), regid INT(30), classname VARCHAR(30))")

# %%
cursor.execute("use pysqldb")  #because when ever we are  inserting data it should not get confuse in which database it have to enter it

# %%
cursor.execute("show tables")

# %%
cursor.fetchall()
# Out:
# [('pu',)]

# %%
cursor.execute('''insert into pysqldb.pu values(34, "sourav", "kumar", 12, "DS")''')

# %%
#now only we not be able to see the data"

#so we have to commit which save the data

mydb.commit()   #whenver we try to insert any data make sure to commit coonection string >> if we don't do it we  will  not be able to see any data 
#inside the table

# %%
cursor.execute("select * from pu")

# %%
cursor.fetchall()
# Out:
# [(34, 'sourav', 'kumar', 12, 'DS')]

# %%
## to upload a data in mysql using python>>

# %%
ls
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is 8848-02FD
#
#  Directory of C:\Users\ASUS\data science\sql\sqlpy_connection
#
# 04-08-2025  23:39    <DIR>          .
# 04-08-2025  22:37    <DIR>          ..
# 04-08-2025  21:59    <DIR>          .ipynb_checkpoints
# 04-08-2025  23:34            44,286 Connection_to_mysql.ipynb
# 04-08-2025  23:39            11,903 glass.data
#                2 File(s)         56,189 bytes
#                3 Dir(s)  73,472,667,648 bytes free

# %%
#to show the data in csv file >> glass.data>>

# %%
import csv
with open("glass.data", "r") as f:
    glass_data = csv.reader(f, delimiter = '\n')
    for i in glass_data:
        print(i)
# Out:
# ['1,1.52101,13.64,4.49,1.10,71.78,0.06,8.75,0.00,0.00,1']
# ['2,1.51761,13.89,3.60,1.36,72.73,0.48,7.83,0.00,0.00,1']
# ['3,1.51618,13.53,3.55,1.54,72.99,0.39,7.78,0.00,0.00,1']
# ['4,1.51766,13.21,3.69,1.29,72.61,0.57,8.22,0.00,0.00,1']
# ['5,1.51742,13.27,3.62,1.24,73.08,0.55,8.07,0.00,0.00,1']
# ['6,1.51596,12.79,3.61,1.62,72.97,0.64,8.07,0.00,0.26,1']
# ['7,1.51743,13.30,3.60,1.14,73.09,0.58,8.17,0.00,0.00,1']
# ['8,1.51756,13.15,3.61,1.05,73.24,0.57,8.24,0.00,0.00,1']
# ['9,1.51918,14.04,3.58,1.37,72.08,0.56,8.30,0.00,0.00,1']
# ['10,1.51755,13.00,3.60,1.36,72.99,0.57,8.40,0.00,0.11,1']
# ['11,1.51571,12.72,3.46,1.56,73.20,0.67,8.09,0.00,0.24,1']
# ['12,1.51763,12.80,3.66,1.27,73.01,0.60,8.56,0.00,0.00,1']
# ['13,1.51589,12.88,3.43,1.40,73.28,0.69,8.05,0.00,0.24,1']
# ['14,1.51748,12.86,3.56,1.27,73.21,0.54,8.38,0.00,0.17,1']
# ['15,1.51763,12.61,3.59,1.31,73.29,0.58,8.50,0.00,0.00,1']
# ['16,1.51761,12.81,3.54,1.23,73.24,0.58,8.39,0.00,0.00,1']
# ...

# %%
import csv
with open("glass.data", "r") as f:
    glass_data = csv.reader(f, delimiter = '\n')
    for i in glass_data:
        print(i[0])
# Out:
# 1,1.52101,13.64,4.49,1.10,71.78,0.06,8.75,0.00,0.00,1
# 2,1.51761,13.89,3.60,1.36,72.73,0.48,7.83,0.00,0.00,1
# 3,1.51618,13.53,3.55,1.54,72.99,0.39,7.78,0.00,0.00,1
# 4,1.51766,13.21,3.69,1.29,72.61,0.57,8.22,0.00,0.00,1
# 5,1.51742,13.27,3.62,1.24,73.08,0.55,8.07,0.00,0.00,1
# 6,1.51596,12.79,3.61,1.62,72.97,0.64,8.07,0.00,0.26,1
# 7,1.51743,13.30,3.60,1.14,73.09,0.58,8.17,0.00,0.00,1
# 8,1.51756,13.15,3.61,1.05,73.24,0.57,8.24,0.00,0.00,1
# 9,1.51918,14.04,3.58,1.37,72.08,0.56,8.30,0.00,0.00,1
# 10,1.51755,13.00,3.60,1.36,72.99,0.57,8.40,0.00,0.11,1
# 11,1.51571,12.72,3.46,1.56,73.20,0.67,8.09,0.00,0.24,1
# 12,1.51763,12.80,3.66,1.27,73.01,0.60,8.56,0.00,0.00,1
# 13,1.51589,12.88,3.43,1.40,73.28,0.69,8.05,0.00,0.24,1
# 14,1.51748,12.86,3.56,1.27,73.21,0.54,8.38,0.00,0.17,1
# 15,1.51763,12.61,3.59,1.31,73.29,0.58,8.50,0.00,0.00,1
# 16,1.51761,12.81,3.54,1.23,73.24,0.58,8.39,0.00,0.00,1
# 17,1.51784,12.68,3.67,1.16,73.11,0.61,8.70,0.00,0.00,1
# ...

# %%
#to load this data in database>>

# %%
#first step is we have to create table

#and then by insert command we load data

# %%
import mysql.connector as conn

# %%
mydb1 = conn.connect(host ="localhost", user= "root", passwd = "Deoghar@baba5")

# %%
cursor = mydb1.cursor()

# %%
cursor.execute('create table pysqldb.glassdata(col1 INT(10) ,col2 float(10,5),col3 float(10,5) ,col4 float(10,5) , col5 float(10,5),col6 float(10,5) ,clo7 float(10,5) , col8 float(10,5) , col9 float(10,5) , col10 float(10,5) , col11 INT(10)) ')

# %%
#firt way to insert the data is to insert each row data one by one 


#or  the other way to  inter data in one go

#for that >>

# %%
#first way>>
cursor.execute('insert into pysqldb.glassdata values(1,1.52101,13.64,4.49,1.10,71.78,0.06,8.75,0.00,0.00,1)')

# %%
mydb1.commit()

# %%
#now to load entire data in one go>>

# %%
with open('glass.data', 'r') as f:
    glass_data = csv.reader(f, delimiter = '\n')
    for i in glass_data:
        print(type(i[0]))
        print(f"insert into glassdata values ({str(i[0])})")         
        cursor.execute(f"insert into pysqldb.glassdata values({str(i[0])})")           #since pythom always take input as string
# Out:
# <class 'str'>
# insert into glassdata values (1,1.52101,13.64,4.49,1.10,71.78,0.06,8.75,0.00,0.00,1)
# <class 'str'>
# insert into glassdata values (2,1.51761,13.89,3.60,1.36,72.73,0.48,7.83,0.00,0.00,1)
# <class 'str'>
# insert into glassdata values (3,1.51618,13.53,3.55,1.54,72.99,0.39,7.78,0.00,0.00,1)
# <class 'str'>
# insert into glassdata values (4,1.51766,13.21,3.69,1.29,72.61,0.57,8.22,0.00,0.00,1)
# <class 'str'>
# insert into glassdata values (5,1.51742,13.27,3.62,1.24,73.08,0.55,8.07,0.00,0.00,1)
# <class 'str'>
# insert into glassdata values (6,1.51596,12.79,3.61,1.62,72.97,0.64,8.07,0.00,0.26,1)
# <class 'str'>
# insert into glassdata values (7,1.51743,13.30,3.60,1.14,73.09,0.58,8.17,0.00,0.00,1)
# <class 'str'>
# insert into glassdata values (8,1.51756,13.15,3.61,1.05,73.24,0.57,8.24,0.00,0.00,1)
# <class 'str'>
# insert into glassdata values (9,1.51918,14.04,3.58,1.37,72.08,0.56,8.30,0.00,0.00,1)
# <class 'str'>
# ...

# %%
mydb1.commit()

# %%
#now whole data is loded

# %%
#to see the data here aslo>>

# %%
cursor.execute('select * from pysqldb.glassdata')

# %%
cursor.fetchall()
# Out:
# [(1, 1.52101, 13.64, 4.49, 1.1, 71.78, 0.06, 8.75, 0.0, 0.0, 1),
#  (1, 1.52101, 13.64, 4.49, 1.1, 71.78, 0.06, 8.75, 0.0, 0.0, 1),
#  (1, 1.52101, 13.64, 4.49, 1.1, 71.78, 0.06, 8.75, 0.0, 0.0, 1),
#  (1, 1.52101, 13.64, 4.49, 1.1, 71.78, 0.06, 8.75, 0.0, 0.0, 1),
#  (2, 1.51761, 13.89, 3.6, 1.36, 72.73, 0.48, 7.83, 0.0, 0.0, 1),
#  (3, 1.51618, 13.53, 3.55, 1.54, 72.99, 0.39, 7.78, 0.0, 0.0, 1),
#  (4, 1.51766, 13.21, 3.69, 1.29, 72.61, 0.57, 8.22, 0.0, 0.0, 1),
#  (5, 1.51742, 13.27, 3.62, 1.24, 73.08, 0.55, 8.07, 0.0, 0.0, 1),
#  (6, 1.51596, 12.79, 3.61, 1.62, 72.97, 0.64, 8.07, 0.0, 0.26, 1),
#  (7, 1.51743, 13.3, 3.6, 1.14, 73.09, 0.58, 8.17, 0.0, 0.0, 1),
#  (8, 1.51756, 13.15, 3.61, 1.05, 73.24, 0.57, 8.24, 0.0, 0.0, 1),
#  (9, 1.51918, 14.04, 3.58, 1.37, 72.08, 0.56, 8.3, 0.0, 0.0, 1),
#  (10, 1.51755, 13.0, 3.6, 1.36, 72.99, 0.57, 8.4, 0.0, 0.11, 1),
#  (11, 1.51571, 12.72, 3.46, 1.56, 73.2, 0.67, 8.09, 0.0, 0.24, 1),
# ...

# %%
#we can ever read the data using padas also>>

import pandas as pd

# %%
pd.read_sql('select * from pysqldb.glassdata', mydb1)
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_13136\861546700.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   pd.read_sql('select * from pysqldb.glassdata', mydb1)
#      col1     col2   col3  col4  col5   col6  clo7  col8  col9  col10  col11
# 0       1  1.52101  13.64  4.49  1.10  71.78  0.06  8.75  0.00    0.0      1
# 1       1  1.52101  13.64  4.49  1.10  71.78  0.06  8.75  0.00    0.0      1
# 2       1  1.52101  13.64  4.49  1.10  71.78  0.06  8.75  0.00    0.0      1
# 3       1  1.52101  13.64  4.49  1.10  71.78  0.06  8.75  0.00    0.0      1
# 4       2  1.51761  13.89  3.60  1.36  72.73  0.48  7.83  0.00    0.0      1
# ..    ...      ...    ...   ...   ...    ...   ...   ...   ...    ...    ...
# 212   210  1.51623  14.14  0.00  2.88  72.61  0.08  9.18  1.06    0.0      7
# ...

# %%
#to show all databases>>

# %%
pd.read_sql('show databases', mydb1)
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_13136\382322112.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   pd.read_sql('show databases', mydb1)
#              Database
# 0              ds_sql
# 1  information_schema
# 2               mysql
# 3  performance_schema
# 4             pysqldb
# 5              sourav
# 6                 sys

# %%
with open('glass.data', 'r') as f:
    glass_data = csv.reader(f, delimiter = '\n')
    print(glass_data)

# %%
# ✅ What does csv.reader(f, delimiter='\n') return?
# You're reading a CSV file where each line is a single row. Because your delimiter is \n, each row returned by csv.reader is actually a list with one string, like this:

# python
# Copy
# Edit
# i = ['1,2,3,4,5']
# So i[0] is the string '1,2,3,4,5'.

# ✅ Why not use just i[0] directly in SQL?
# Let’s look at this line:

# python
# Copy
# Edit
# cursor.execute(f"insert into pysqldb.glassdata values({str(i[0])})")
# If you wrote:

# python
# Copy
# Edit
# cursor.execute(f"insert into pysqldb.glassdata values({i[0]})")
# Then i[0] is still a string, like '1,2,3,4,5'.

# But here's the catch — inside an f-string, if i[0] is already a string, Python will not automatically wrap it in quotes unless you do it yourself.

# So this will generate a SQL string like:

# sql
# Copy
# Edit
# insert into pysqldb.glassdata values(1,2,3,4,5)
# Which is correct SQL only if those values are all numeric.

# But if i[0] contains even one string column like:

# python
# Copy
# Edit
# i[0] = "1,2,3,'Window',4"
# Then SQL will error out, because it needs quotes around strings properly — and your single big string might break SQL syntax if not formatted correctly.

# ✅ So why use str(i[0])?
# Actually, in this case:

# python
# Copy
# Edit
# str(i[0]) == i[0]
# Because i[0] is already a string. So using str(i[0]) doesn’t change the value, but might have been written:

# For clarity.

# Or mistakenly thinking it's needed.

# But this is not safe for real SQL inserts, because it doesn’t escape or format the values correctly.

# 🔥 Better Way (Recommended)
# You should split the string into actual values, and use parameterized queries to avoid SQL injection or formatting issues:

# python
# Copy
# Edit
# import csv

# with open('glass.data', 'r') as f:
#     glass_data = csv.reader(f)
#     for row in glass_data:
#         values = row[0].split(',')  # Split the single string into a list
#         cursor.execute("INSERT INTO pysqldb.glassdata VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?, ?)", values)
# Replace the number of ? with however many columns your table has.
